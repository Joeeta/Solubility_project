# %% [markdown]
# <a href="https://colab.research.google.com/github/Joeeta/Solubility_project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# **Data Importing and Processing**

# %%
df = pd.read_csv('/content/solubility-dataset.csv')
df.head()
# Out:
#    Solubility    MolWt  MolLogP     MolMR  HeavyAtomCount  NumHAcceptors  \
# 0   -3.616127  392.510   3.9581  102.4454              23              0
# 1   -3.254767  169.183   2.4055   51.9012              13              1
# 2   -2.177078  140.569   2.1525   36.8395               9              1
# 3   -3.924409  756.226   8.1161  200.7106              53              6
# 4   -4.662065  422.525   2.4854  119.0760              31              6
#
#    NumHDonors  NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# 0           0               2                 17                  142
# 1           1               2                  0                   62
# 2           0               2                  1                   46
# 3           2               7                 10                  264
# 4           0               6                 12                  164
#
#    NumAromaticRings  NumSaturatedRings  NumAliphaticRings  RingCount    TPSA
# 0                 0                  0                  0          0    0.00
# 1                 2                  0                  1          3   29.10
# 2                 1                  0                  0          1   17.07
# 3                 6                  0                  0          6  120.72
# 4                 2                  4                  4          6   56.60

# %%
x = df.drop('Solubility', axis=1)
x
# Out:
#         MolWt  MolLogP     MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  \
# 0     392.510  3.95810  102.4454              23              0           0
# 1     169.183  2.40550   51.9012              13              1           1
# 2     140.569  2.15250   36.8395               9              1           0
# 3     756.226  8.11610  200.7106              53              6           2
# 4     422.525  2.48540  119.0760              31              6           0
# ...       ...      ...       ...             ...            ...         ...
# 9977  264.369  2.61700   78.6762              19              4           1
# 9978  444.440 -0.21440  109.5409              32              9           6
# 9979  150.221  2.82402   46.9328              11              1           1
# 9980  454.611  5.09308  131.6560              33              6           0
# 9981  308.333  3.60960   87.7318              23              4           1
#
#       NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# 0                  2                 17                  142
# 1                  2                  0                   62
# 2                  2                  1                   46
# 3                  7                 10                  264
# 4                  6                 12                  164
# ...              ...                ...                  ...
# 9977               4                  8                  106
# 9978              10                  2                  170
# 9979               1                  1                   60
# 9980               6                 13                  180
# 9981               4                  4                  116
#
#       NumAromaticRings  NumSaturatedRings  NumAliphaticRings  RingCount  \
# 0                    0                  0                  0          0
# 1                    2                  0                  1          3
# 2                    1                  0                  0          1
# 3                    6                  0                  0          6
# 4                    2                  4                  4          6
# ...                ...                ...                ...        ...
# 9977                 1                  0                  0          1
# 9978                 1                  0                  3          4
# 9979                 1                  0                  0          1
# 9980                 2                  0                  0          2
# 9981                 3                  0                  0          3
#
#         TPSA
# 0       0.00
# 1      29.10
# 2      17.07
# 3     120.72
# 4      56.60
# ...      ...
# 9977   41.57
# 9978  181.62
# 9979   20.23
# 9980   63.95
# 9981   67.51
#
# [9982 rows x 14 columns]

# %%
y = df.Solubility
y
# Out:
# 0      -3.616127
# 1      -3.254767
# 2      -2.177078
# 3      -3.924409
# 4      -4.662065
#           ...
# 9977   -3.010000
# 9978   -2.930000
# 9979   -2.190000
# 9980   -3.980000
# 9981   -4.780000
# Name: Solubility, Length: 9982, dtype: float64

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=90)

# %%
x_train
# Out:
#         MolWt  MolLogP    MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  \
# 4178  159.060 -6.58780  27.9634               8              2           2
# 6398  310.371  4.56120  81.0055              20              5           0
# 2782  264.284  3.90504  76.9150              20              4           0
# 7914  160.220  1.66910  51.0571              12              1           2
# 2484  161.160  1.48358  42.4660              12              3           0
# ...       ...      ...      ...             ...            ...         ...
# 9539  237.255  0.29410  61.4473              17              4           1
# 6815  173.171  2.94330  51.0678              13              3           1
# 5746  201.225  2.84032  57.8402              15              2           1
# 2717  120.104 -0.87420  25.0538               8              4           1
# 3931  166.132  1.08300  40.3606              12              2           2
#
#       NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# 4178               4                  0                   52
# 6398               6                 15                  122
# 2782               4                  3                   98
# 7914               2                  2                   62
# 2484               3                  1                   60
# ...              ...                ...                  ...
# 9539               5                  5                   92
# 6815               3                  1                   64
# 5746               3                  2                   76
# 2717               4                  3                   48
# 3931               4                  2                   62
#
#       NumAromaticRings  NumSaturatedRings  NumAliphaticRings  RingCount   TPSA
# 4178                 0                  1                  1          1  24.06
# 6398                 0                  0                  0          0  53.99
# 2782                 2                  0                  0          2  58.86
# 7914                 2                  0                  0          2  41.81
# 2484                 1                  0                  0          1  50.09
# ...                ...                ...                ...        ...    ...
# 9539                 1                  0                  0          1  66.84
# 6815                 2                  0                  0          2  49.66
# 5746                 2                  0                  0          2  42.24
# 2717                 0                  0                  0          0  55.76
# 3931                 1                  0                  0          1  74.60
#
# [7985 rows x 14 columns]

# %%
y_train
# Out:
# 4178    0.411200
# 6398   -2.646800
# 2782   -2.308128
# 7914   -3.300000
# 2484   -1.799017
#           ...
# 9539   -1.090000
# 6815   -2.539500
# 5746   -3.303700
# 2717    0.920443
# 3931   -4.044400
# Name: Solubility, Length: 7985, dtype: float64

# %%
x_test
# Out:
#         MolWt  MolLogP     MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  \
# 3299  228.288   1.9190   58.7140              16              4           0
# 4026  118.132   0.1959   28.5090               8              3           0
# 9494  249.314   3.3614   70.0023              18              3           1
# 4758  142.585   1.8323   37.3748               9              1           1
# 4707  109.128   0.3853   31.6830               8              2           0
# ...       ...      ...       ...             ...            ...         ...
# 1155  212.296   3.8034   69.8894              16              2           2
# 2812  143.937  -0.3589    2.0595               4              3           0
# 5695  780.949   2.2181  192.6108              55             14           6
# 1284  308.293   3.7059   86.6624              23              4           2
# 604    88.150   1.0248   26.5408               6              1           1
#
#       NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# 3299               4                  4                   92
# 4026               3                  3                   48
# 9494               5                  6                   98
# 4758               2                  1                   48
# 4707               2                  0                   42
# ...              ...                ...                  ...
# 1155               2                  1                   82
# 2812               4                  0                   24
# 5695              14                  7                  312
# 1284               6                  3                  114
# 604                1                  2                   38
#
#       NumAromaticRings  NumSaturatedRings  NumAliphaticRings  RingCount  \
# 3299                 0                  1                  1          1
# 4026                 0                  0                  0          0
# 9494                 1                  0                  0          1
# 4758                 1                  0                  0          1
# 4707                 1                  0                  0          1
# ...                ...                ...                ...        ...
# 1155                 2                  0                  1          3
# 2812                 0                  0                  0          0
# 5695                 0                  7                  8          8
# 1284                 3                  0                  0          3
# 604                  0                  0                  0          0
#
#         TPSA
# 3299   52.60
# 4026   35.53
# 9494   65.26
# 4758   20.23
# 4707   22.00
# ...      ...
# 1155   24.06
# 2812   51.21
# 5695  203.06
# 1284   92.47
# 604    20.23
#
# [1997 rows x 14 columns]

# %%
y_test
# Out:
# 3299   -2.251273
# 4026    0.927600
# 9494   -1.790000
# 4758   -1.756100
# 4707    0.962100
#           ...
# 1155   -3.247761
# 2812   -2.158172
# 5695   -4.081100
# 1284   -6.643866
# 604    -0.468101
# Name: Solubility, Length: 1997, dtype: float64

# %% [markdown]
# **Linear Regression Model**

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)

# %%
y_pred_train = reg.predict(x_train)
y_pred_test = reg.predict(x_test)

# %%
reg_train_mse = mean_squared_error(y_train, y_pred_train)
reg_train_r2 = r2_score(y_train, y_pred_train)

reg_test_mse= mean_squared_error(y_test, y_pred_test)
reg_test_r2= r2_score(y_test, y_pred_test)

print(reg_train_mse)
print(reg_train_r2)
print(reg_test_mse)
print(reg_test_r2)
# Out:
# 2.9603704504534574
# 0.4726844297682061
# 2.7747976860652415
# 0.5028292232089109

# %% [markdown]
# **Visualisation**

# %%
plt.figure(figsize=(6,6))
plt.scatter(x=y_train, y=y_pred_train, c='hotpink', alpha=0.1)
z = np.polyfit(y_train, y_pred_train, 1)
p = np.poly1d(z)
plt.plot(y_train,p(y_train),'red')
plt.ylabel('Predicted Solubility')
plt.xlabel('Experimental Solubility')
# Out:
# Text(0.5, 0, 'Experimental Solubility')
